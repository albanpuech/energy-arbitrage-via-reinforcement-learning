# %%
import pandas as pd
import numpy as np

from dataset import get_dataset, add_derivatives
from env_continuous import Battery
from qlearning import QLearning

from sklearn.preprocessing import MinMaxScaler

from tqdm import tqdm

from plot import display_profit, display_schedule
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import datetime
import warnings

from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import DQN

# %%
df = get_dataset()

# %%
df_train = df[df.timestamp.dt.year==2020].reset_index(drop=True)
df_test = df[df.timestamp.dt.year==2021].reset_index(drop=True)

# %%
def add_rolling_history_prices(df, n_days=14, k=3):
    cols = []
    df["p_0"] = df.price / df.price.rolling(n_days*24).mean()
    cols.append("p_0")

    for i in range(1, k):
        cols.append(f"p_{i}")
        df[f"p_{i}"] = df[f"p_{i-1}"].shift(1)

    # def get_price(i):
    #     if i - (24*n_days) < 0:
    #         return np.nan
    #     return df.p_0[i-(24*(n_days)):i:24].mean()
    
    df["h_0"] = df_train.p_0.rolling(n_days*24).apply(lambda x: x[::24].mean())
    # df["h_0"] = np.array([get_price(i) for i in range(len(df))])
    cols.append("h_0")

    for h in range(1, 24):
        col_name = f"h_{h}"
        df[col_name] = df[f"h_{h-1}"].shift(1)
        cols.append(str(col_name))

    return df, cols

# %%
n_days = 14
k = 5
df_train, cols = add_rolling_history_prices(df_train, n_days=n_days, k=k)
df_test, cols = add_rolling_history_prices(df_test, n_days=n_days, k=k)

# %%
start_hour = (n_days * 24 * 2) + max(24, k) - 3

def reward(env, action):
    if action == 2:
        return -env.df.price[env.hour] 
    
    if action == 0:
        return env.df.price[env.hour]
    
    return 0

train_env = Battery(df_train,cols,start_hour=start_hour, reward_function=reward)
train_env_copy = Battery(df_train,cols,start_hour=start_hour, reward_function=reward)
test_env = Battery(df_test,cols,start_hour=start_hour, reward_function=reward)

# %%
check_env(train_env)

# %%
from stable_baselines3.common.callbacks import EvalCallback, CallbackList, BaseCallback

class Cometlogger(BaseCallback):

    """
    Custom callback to plot additional values in comet.
    """

    def __init__(self, experiment, train_env_copy,test_env,eval_freq=10000):

        super(Cometlogger, self).__init__()
        self.test_env = test_env
        self.train_env = train_env_copy
        self.eval_freq = eval_freq
        self.experiment = experiment

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:

            reward_train, df_optim_train = self.train_env.test(self.model)
            reward_test, df_optim_test = self.test_env.test(self.model)

            profit_train = - (df_optim_train.price * df_optim_train.schedule).sum() / 10**6
            profit_test = - (df_optim_test.price * df_optim_test.schedule).sum() / 10**6

            self.experiment.log_metric("profit_train",profit_train )
            self.experiment.log_metric("profit_test",profit_test )

            self.experiment.log_metric("reward_train",reward_train )
            self.experiment.log_metric("reward_test",reward_test)
            print("---------")
            print("profit_train ", profit_train)
            print("profit_test ", profit_test)
            print("---------")

        return True

# %%
# Import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="GYoAMnAcbnbZ9p1PurkZCaSX0",
    project_name="battery-rl",
    workspace="albanpuech",
)

# Report multiple hyperparameters using a dictionary:
hyper_params = {
    "k":k,
    
#
}
experiment.log_parameters(hyper_params)
# Out:
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorboard. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/albanpuech/battery-rl/b1136009b30a42dd98b4129a0680948c
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (34.54 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorboard. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/albanpuech/battery-rl/6559924d97f9492a8072a065ac686242

# %%
train_env.reset()

model = DQN("MlpPolicy", train_env, verbose=1)



logger_callback = Cometlogger(experiment, train_env_copy, test_env,
                              eval_freq=50000)

callback = CallbackList([logger_callback])

model.learn(total_timesteps=len(df_train)*500, callback=callback)
experiment.end()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 1.9e+04  |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4811     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 32360    |
# ----------------------------------
# ---------
# profit_train  -34.069
# profit_test  -62.632
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 2.08e+04 |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1207     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 64720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.04     |
# |    n_updates        | 3679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 2.46e+04 |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 788      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 97080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.82     |
# |    n_updates        | 11769    |
# ----------------------------------
# ---------
# profit_train  795.339
# profit_test  2746.495
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 2.79e+04 |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 607      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 129440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.64     |
# |    n_updates        | 19859    |
# ----------------------------------
# ---------
# profit_train  882.546
# profit_test  2795.2195
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 3.1e+04  |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 537      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 161800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.18     |
# |    n_updates        | 27949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 3.4e+04  |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 522      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 194160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.44     |
# |    n_updates        | 36039    |
# ----------------------------------
# ---------
# profit_train  872.436
# profit_test  2822.355
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 3.7e+04  |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 493      |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 226520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.23     |
# |    n_updates        | 44129    |
# ----------------------------------
# ---------
# profit_train  892.128
# profit_test  2808.176
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 4.01e+04 |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 471      |
# |    time_elapsed     | 548      |
# |    total_timesteps  | 258880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.48     |
# |    n_updates        | 52219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 4.3e+04  |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 466      |
# |    time_elapsed     | 623      |
# |    total_timesteps  | 291240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.01     |
# |    n_updates        | 60309    |
# ----------------------------------
# ---------
# profit_train  859.846
# profit_test  2724.799
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 4.59e+04 |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 443      |
# |    time_elapsed     | 728      |
# |    total_timesteps  | 323600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.98     |
# |    n_updates        | 68399    |
# ----------------------------------
# ---------
# profit_train  844.499
# profit_test  2620.6105
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 4.89e+04 |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 428      |
# |    time_elapsed     | 830      |
# |    total_timesteps  | 355960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.04     |
# |    n_updates        | 76489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 5.19e+04 |
# |    exploration_rate | 0.16     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 423      |
# |    time_elapsed     | 916      |
# |    total_timesteps  | 388320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.92     |
# |    n_updates        | 84579    |
# ----------------------------------
# ---------
# profit_train  829.6445
# profit_test  2591.76
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 5.5e+04  |
# |    exploration_rate | 0.09     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 412      |
# |    time_elapsed     | 1020     |
# |    total_timesteps  | 420680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15       |
# |    n_updates        | 92669    |
# ----------------------------------
# ---------
# profit_train  819.7445
# profit_test  2425.286
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 5.81e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 399      |
# |    time_elapsed     | 1132     |
# |    total_timesteps  | 453040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.83     |
# |    n_updates        | 100759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 6.11e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 393      |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 485400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.53     |
# |    n_updates        | 108849   |
# ----------------------------------
# ---------
# profit_train  846.103
# profit_test  2477.568
# ---------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09e+03 |
# |    ep_rew_mean      | 6.35e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 381      |
# |    time_elapsed     | 1355     |
# |    total_timesteps  | 517760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.8      |
# |    n_updates        | 116939   |
# ----------------------------------

# %%
cum_reward, df_optim = test_env.test(model)

display_schedule(df_optim)

display_profit(df_optim)
# Out:
# <div>                            <div id="8f51e1ca-b706-4b65-a67c-42eaa9ac175d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f51e1ca-b706-4b65-a67c-42eaa9ac175d")) {                    Plotly.newPlot(                        "8f51e1ca-b706-4b65-a67c-42eaa9ac175d",                        [{"line":{"shape":"hv"},"name":"Price (EUR/MWh)","showlegend":true,"x":["2021-01-01T00:00:00","2021-01-01T01:00:00","2021-01-01T02:00:00","2021-01-01T03:00:00","2021-01-01T04:00:00","2021-01-01T05:00:00","2021-01-01T06:00:00","2021-01-01T07:00:00","2021-01-01T08:00:00","2021-01-01T09:00:00","2021-01-01T10:00:00","2021-01-01T11:00:00","2021-01-01T12:00:00","2021-01-01T13:00:00","2021-01-01T14:00:00","2021-01-01T15:00:00","2021-01-01T16:00:00","2021-01-01T17:00:00","2021-01-01T18:00:00","2021-01-01T19:00:00","2021-01-01T20:00:00","2021-01-01T21:00:00","2021-01-01T22:00:00","2021-01-01T23:00:00","2021-01-02T00:00:00","2021-01-02T01:00:00","2021-01-02T02:00:00","2021-01-02T03:00:00","2021-01-02T04:00:00","2021-01-02T05:00:00","2021-01-02T06:00:00","2021-01-02T07:00:00","2021-01-02T08:00:00","2021-01-02T09:00:00","2021-01-02T10:00:00","2021-01-02T11:00:00","2021-01-02T12:00:00","2021-01-02T13:00:00","2021-01-02T14:00:00","2021-01-02T15:00:00","2021-01-02T16:00:00","2021-01-02T17:00:00","2021-01-02T18:00:00","2021-01-02T19:00:00","2021-01-02T20:00:00","2021-01-02T21:00:00","2021-01-02T22:00:00","2021-01-02T23:00:00","2021-01-03T00:00:00","2021-01-03T01:00:00","2021-01-03T02:00:00","2021-01-03T03:00:00","2021-01-03T04:00:00","2021-01-03T05:00:00","2021-01-03T06:00:00","2021-01-03T07:00:00","2021-01-03T08:00:00","2021-01-03T09:00:00","2021-01-03T10:00:00","2021-01-03T11:00:00","2021-01-03T12:00:00","2021-01-03T13:00:00","2021-01-03T14:00:00","2021-01-03T15:00:00","2021-01-03T16:00:00","2021-01-03T17:00:00","2021-01-03T18:00:00","2021-01-03T19:00:00","2021-01-03T20:00:00","2